# %% [markdown]
# pandas
# - initialization
# - colomn selection,

# %%
pip install pandas

# %%
import pandas as pd

# %%
data_penjualan = {
    "product": ["product A", "product B",]
}

# %%
df = pd.read_csv("Data_Penumpang Bus Sekolah Tahun 2021.csv")
df.head()
# Out:
#    periode_data                type_operasi    area_operasi  jumlah_bus  \
# 0        202101         Puskesmas Cilincing  RS Wisma Atlet         1.0
# 1        202101             Puskesmas Tebet  RS Wisma Atlet         1.0
# 2        202101     Puskesmas Cempaka Putih  RS Wisma Atlet         1.0
# 3        202101     Puskesmas Tanjung Priok  RS Wisma Atlet         1.0
# 4        202101  Puskesmas Ciracas Tahap II  RS Wisma Atlet         1.0
#
#    jumlah_penumpang
# 0               8.0
# 1              24.0
# 2              14.0
# 3              10.0
# 4               9.0

# %%
df.sample(10)
# Out:
#       periode_data             type_operasi    area_operasi  jumlah_bus  \
# 2228        202108          RSUD PASAR REBO          BEKASI        31.0
# 674         202102         RSUD DUREN SAWIT           BOGOR         NaN
# 1168        202106  Puskesmas Kelapa Gading  RS Wisma Atlet         1.0
# 734         202102  RS JANTUNG HARAPAN KITA          BEKASI        19.0
# 872         202104         RSUD DUREN SAWIT          BEKASI         NaN
# 1285        202106         RSUD DUREN SAWIT          BEKASI         NaN
# 852         202103        Puskesmas Ciracas  RS Wisma Atlet         1.0
# 487         202102       Puskesmas Cipayung  RS Wisma Atlet         1.0
# 2246        202108                  R S C M           DEPOK        46.0
# 979         202103       Puskesmas Cipayung  RS Wisma Atlet         1.0
#
#       jumlah_penumpang
# 2228             785.0
# 674                NaN
# 1168               6.0
# 734              733.0
# 872                NaN
# 1285               NaN
# ...
